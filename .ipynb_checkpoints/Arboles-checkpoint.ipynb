# %% [markdown]
# # Árboles
#
# Vamos a construir un arbol, creando una linea vertical, y luego desde su extremo, vamos a crear dos lineas nuevas, en direcciones de 60° y -60°, cuya longitud sea la mitad de la original.

# %%
import math
import matplotlib.pyplot as pl

# %%
def euclidMetric(x1,y1,x2,y2):
    return(math.sqrt((x2-x1)**2 + (y2-y1)**2))

# %%
depth= 5

class Tree():
    def __init__(self,root):
        self.root = root
        self.children = []
    def addNode(self,obj):
        self.children.append(obj)
class Node:
    def __init__(self,data):
        self.data = data
        self.children = []
    def addNode(self,obj):
        self.children.append(obj)

#trunk = Tree(Node([5,0,5,1])) ##First line
trunk = Node([5,0,5,1])
def addBranches(prev, node, level, depth):
    for i in range(2):
        print(i)
        origx=prev[2]
        origy=prev[3]
        length=euclidMetric(prev[0],prev[1],prev[2],prev[3])/2
        if i == 0:
            angle = 60
            print("right")
        if i ==1:
            angle= 120
            print("left")
        newY= origy+length*math.sin(math.radians(angle))
        newX = origx + length*math.cos(math.radians(angle))
        newNode=Node([origx,origy,newX, newY])
        node.addNode(newNode)
        if level < depth:
            level+=1
            print("Level" +str(level))
            addBranches(newNode.data, newNode,level, depth)
            level-=1
            
addBranches(trunk.data, trunk,0,depth)
# Out:
# 0
# right
# Level1
# 0
# right
# Level2
# 0
# right
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level2
# 0
# right
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level1
# 0
# right
# Level2
# 0
# right
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level2
# 0
# right
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left

# %%
print(trunk.children[0].data)
print(trunk.children[1].data)
print(trunk.children[0].children[0].data)
print(trunk.children[0].children[1].data)
print(trunk.children[1].children[0].data)
print(trunk.children[1].children[1].data)
print(trunk.children[1].children[1].children[0].data)
print(trunk.children[1].children[1].children[1].data)
print(trunk.children[1].children[0].children[0].children[0].children[0].data)
# Out:
# [5, 1, 5.25, 1.4330127018922192]
# [5, 1, 4.75, 1.4330127018922194]
# [5.25, 1.4330127018922192, 5.375, 1.6495190528383288]
# [5.25, 1.4330127018922192, 5.125, 1.6495190528383288]
# [4.75, 1.4330127018922194, 4.875, 1.649519052838329]
# [4.75, 1.4330127018922194, 4.625, 1.6495190528383292]
# [4.625, 1.6495190528383292, 4.6875, 1.7577722283113841]
# [4.625, 1.6495190528383292, 4.5625, 1.7577722283113841]
# [4.96875, 1.811898816047911, 4.984375, 1.8389621099161748]

# %%
fig = pl.figure(figsize=(12,12))
fig.suptitle("Arbol con ramas en 60 grados", fontsize=16)

def goThroughBranches(node):
    pl.plot([node.data[0],node.data[2]],[node.data[1],node.data[3]])
    for child in node.children:
        goThroughBranches(child)

goThroughBranches(trunk)

# %% [markdown]
# ### Analisis de la longitud de las ramas
#
# La primera rama tiene una longitud de 1. Las siguientes 2, tienen una longitud de \frac{1}{2} , por lo que sumadas, tienen tambien una longitud de 1. El siguiente nivel tiene ramas de una longitud de un cuarto, y son 4, por lo que tambien tenemos una longitud de 1.
#
# Se deduce que la longitud de cada iteracion es 1, y por lo tanto, con n iteraciones tendremos una longitud n. Si la figura tiene iteraciones tendiendo a infinito, la longitud sera infinita.

# %% [markdown]
# ## Accumulative angle tree
#
# Now, instead of placing each branch at 60 degrees, we will carry the degree from the last branch and sum it up with 60.

# %%
def addBranchesWithAngleSum(prev, node, level, depth, angle):
    for i in range(2):
        print(i)
        origx=prev[2]
        origy=prev[3]
        length=euclidMetric(prev[0],prev[1],prev[2],prev[3])/2
        if i == 0:
            angle = angle - 60
            print("right")
        if i ==1:
            angle= angle + 120
            print("left")
        newY= origy+length*math.sin(math.radians(angle))
        newX = origx + length*math.cos(math.radians(angle))
        newNode=Node([origx,origy,newX, newY])
        node.addNode(newNode)
        if level < depth:
            level+=1
            print("Level" +str(level))
            addBranchesWithAngleSum(newNode.data, newNode,level, depth, angle)
            level-=1

# %% [markdown]
# Prestar atencion a las lineas 8 y 12 donde la suma se realiza.

# %%
trunkAngleSum = Node([5,0,5,1])

addBranchesWithAngleSum(trunkAngleSum.data,trunkAngleSum,0,5,90)
# Out:
# 0
# right
# Level1
# 0
# right
# Level2
# 0
# right
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level2
# 0
# right
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level1
# 0
# right
# Level2
# 0
# right
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level2
# 0
# right
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level3
# 0
# right
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level4
# 0
# right
# Level5
# 0
# right
# 1
# left
# 1
# left
# Level5
# 0
# right
# 1
# left

# %%
fig2 = pl.figure(figsize=(12,12))
fig2.suptitle("Arboles con ramas a 60 grados, con angulos acumulados en cada iteracion}", fontsize=16)

goThroughBranches(trunkAngleSum)

# %% [markdown]
# Finalmente,
